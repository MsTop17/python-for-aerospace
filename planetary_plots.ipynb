# %%
# !pip install matplotlib pandas
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.11.1-cp312-cp312-win_amd64.whl.metadata (80 kB)
# Requirement already satisfied: pandas in c:\users\tanu_janu\appdata\local\programs\python\python312\lib\site-packages (3.0.3)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: cycler>=0.10 in c:\users\tanu_janu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\tanu_janu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tanu_janu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in c:\users\tanu_janu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\tanu_janu\appdata\roaming\python\python312\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\tanu_janu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\tanu_janu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tanu_janu\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\tanu_janu\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\users\tanu_janu\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.11.1-cp312-cp312-win_amd64.whl (9.3 MB)
# Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Installing collected packages: contourpy, matplotlib
# Successfully installed contourpy-1.3.3 matplotlib-3.11.1
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import pandas as pd

planetary_metrics = {
    'Planet': ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune'],
    'Distance_AU': [0.39, 0.72, 1.00, 1.52, 5.20, 9.58, 19.22, 30.05],
    'Orbital_Period_Years': [0.24, 0.62, 1.00, 1.88, 11.86, 29.46, 84.01, 164.8]
}

df = pd.DataFrame(planetary_metrics)

plt.figure(figsize=(10, 6))
plt.scatter(df['Distance_AU'], df['Orbital_Period_Years'], color='blue', marker='o', s=60, zorder=3)

plt.xscale('log')
plt.xticks([0.3, 0.5, 1.0, 2.0, 5.0, 10.0, 20.0, 30.0], ['0.3', '0.5', '1.0', '2.0', '5.0', '10.0', '20.0', '30.0'])

plt.title('Solar System: Orbital Period vs. Distance from Sun (Log Scale)')
plt.xlabel('Semi-Major Axis Distance (AU) - Logarithmic Scale')
plt.ylabel('Orbital Period (Earth Years)')
plt.grid(True, linestyle='--', alpha=0.5, which="both")

for idx, row in df.iterrows():
    plt.annotate(
        row['Planet'], 
        (row['Distance_AU'], row['Orbital_Period_Years']), 
        textcoords="offset points", 
        xytext=(0, 8), 
        ha='center',
        weight='bold'
    )

plt.tight_layout()
plt.show()
